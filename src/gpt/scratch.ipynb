# %%
def get_word_to_index(vocab):
    # Tokenize starting prompt
    word_to_index = {}
    for index, word in enumerate(vocab):
        word_to_index[word] = index
    return word_to_index

# %%
import json 
with open(f"/home/johnb/Projects/github/gpt-keras-books/src/gpt/config/vocab.json", "r") as vocab_file:
    vocab: dict = json.load(vocab_file)

# %%
word_to_index = get_word_to_index(vocab)

# %%
prompt = "the story is"
start_tokens = [word_to_index.get(_, 1) for _ in prompt.split()]

# %%
start_tokens
# Out:
# [3, 287, 32]

# %%
vocab
# Out:
# ['',
#  '[UNK]',
#  ',',
#  'the',
#  '.',
#  'and',
#  'to',
#  '"',
#  'of',
#  'a',
#  'in',
#  'i',
#  'he',
#  'was',
#  'that',
#  'it',
#  'you',
#  'his',
#  'as',
#  'for',
#  'had',
#  '-',
#  'with',
#  'her',
#  "'s",
#  'on',
#  'at',
#  'but',
#  'she',
#  'said',
#  'be',
#  'not',
#  'is',
#  'they',
#  ';',
#  'have',
#  '?',
#  '!',
#  "'t",
#  'him',
#  'we',
#  'all',
#  'were',
#  'so',
#  '"i',
#  'me',
#  'this',
#  'from',
#  'there',
#  'one',
#  'my',
#  'up',
#  'by',
#  'when',
#  'will',
#  'them',
#  'would',
#  'out',
#  'if',
#  'are',
#  'their',
#  'do',
#  'been',
#  'which',
#  'no',
#  'an',
#  'what',
#  'who',
#  'then',
#  'could',
#  'your',
#  'little',
#  'or',
#  'can',
#  'now',
#  'about',
#  'into',
#  'time',
#  "'",
#  'some',
#  'see',
#  'did',
#  'down',
#  'know',
#  'very',
#  'like',
#  'more',
#  'go',
#  'over',
#  'any',
#  'man',
#  "'ll",
#  'us',
#  'don',
#  'good',
#  'before',
#  'here',
#  'our',
#  'came',
#  'than',
# ...

# %%
len(vocab)
# Out:
# 499
